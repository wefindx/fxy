# %% [markdown]
# # Representing Data

# %%
# from fxy.a import * -- convenience import

# %% [markdown]
# ## **Creating Representations**

# %% [markdown]
# ### **Python's Basic Native Data Types**

# %%
class Person:
    pass

# %% [markdown]
# #### `class`

# %%
me = Person()

# %% [markdown]
# #### `string`

# %%
me.name = 'Alice'

# %% [markdown]
# #### `float`

# %%
me.height = 158.5

# %% [markdown]
# #### `int`

# %%
me.age = 15

# %% [markdown]
# #### `bool`

# %%
me.teaching = True

# %% [markdown]
# #### `list`

# %%
me.times = [1, 2, 3]

# %% [markdown]
# #### `set`

# %%
me.set = set([1, 2, 3])

# %% [markdown]
# #### `tuple` (immutable `list`)

# %%
me.tuple = (1, 2, 3)

# %% [markdown]
# #### `dict`

# %%
me.dict = {'x': [1, 2, 3], 'y': (4, 5)}

# %% [markdown]
# ### **Basic NumPy and Pandas Data Types**

# %%
import numpy as np

# %% [markdown]
# #### `np.array`

# %%
me.array = np.array([184.1, 180.1, 171.4, 177.1])

# %% [markdown]
# #### "`matrix`"

# %%
me.matrix = np.array([[184.1, 180.1],[171.4, 177.1]])

# %%
import pandas as pd

# %% [markdown]
# #### `pd.Index`

# %%
me.index = pd.Index(['a', 'b', 1])

# %% [markdown]
# #### `pd.Series`

# %%
me.s = pd.Series([1, 2, 3])

# %%
me.xseries = pd.Series([1, 2, 3], me.index)

# %% [markdown]
# #### `pd.MultiIndex`

# %%
me.mindex = pd.MultiIndex.from_tuples([('a', 1), ('a', 2), ('b', 1)])

# %%
me.mseries = pd.Series([1, 2, 3], me.mindex)

# %% [markdown]
# #### `pd.DataFrame`

# %%
me.df = pd.DataFrame({'xVar': [1, 2, 3], 'yVar': [4, 5, 6]})

# %%
me.df
# Out:
#    xVar  yVar
# 0     1     4
# 1     2     5
# 2     3     6

# %%
me.yseries = pd.Series([4, 5, 6], ['a', 'b', 2])

# %%
me.dataframe = pd.DataFrame({'xVar': me.xseries, 'yVar': me.yseries})

# %%
me.dataframe
# Out:
#    xVar  yVar
# a   1.0   4.0
# b   2.0   5.0
# 1   3.0   NaN
# 2   NaN   6.0

# %% [markdown]
# #### `pd.Categorical`

# %%
me.categorical = pd.Categorical(['yes', 'no', 'yes', 'yes'])
me.categorical
# Out:
# ['yes', 'no', 'yes', 'yes']
# Categories (2, object): ['no', 'yes']

# %%
me.dataframe['zVar'] = me.categorical
me.dataframe
# Out:
#    xVar  yVar zVar
# a   1.0   4.0  yes
# b   2.0   5.0   no
# 1   3.0   NaN  yes
# 2   NaN   6.0  yes

# %% [markdown]
# ### **Variously Indexed DataFrames**

# %% [markdown]
# #### ``DataFrame from 1 MultiIndex series``

# %%
me.xMseries = pd.Series([1,2,3], pd.MultiIndex.from_tuples([('a', 1), ('a', 2), ('b', 1)]))
me.yMseries = pd.Series([4,5,6], pd.MultiIndex.from_tuples([('a', 1), ('a', 2), ('b', 1)]))
me.Mdataframe = pd.DataFrame({'xVar': me.xMseries, 'yVar': me.yMseries})

# %%
me.Mdataframe
# Out:
#      xVar  yVar
# a 1     1     4
#   2     2     5
# b 1     3     6

# %% [markdown]
# #### ``DataFrame with 2 MultiIndex series``

# %%
me.Mdataframe = pd.DataFrame(np.arange(12).reshape(4,3),
                         index=[['a','a','b','b'], [1,2,1,2]],
                         columns=[['VAR-A','VAR-A', 'VAR-B'],
                                  ['var-a','var-b', 'var-c']])

# %%
me.Mdataframe
# Out:
#     VAR-A       VAR-B
#     var-a var-b var-c
# a 1     0     1     2
#   2     3     4     5
# b 1     6     7     8
#   2     9    10    11

# %% [markdown]
# #### ``Naming Axes``

# %%
me.Mdataframe.index.names = ['/letter/', '/number/']
me.Mdataframe.columns.names = ['/capital/', '/lowercase/']

# %%
me.Mdataframe
# Out:
# /capital/         VAR-A       VAR-B
# /lowercase/       var-a var-b var-c
# /letter/ /number/
# a        1            0     1     2
#          2            3     4     5
# b        1            6     7     8
#          2            9    10    11

# %% [markdown]
# #### ``More Levels``

# %%
me.Mdataframe = pd.DataFrame(np.arange(12).reshape(4,3),
                         index=[['x','x','x','y'],
                                ['a','a','b','b'],
                                [1,2,1,2,]],
                         columns=[['VAR', 'VAR', 'VAR'],
                                  ['VAR-A','VAR-A', 'VAR-B'],
                                  ['var-a','var-b', 'var-c']])
me.Mdataframe.index.names = ['note1　⇣', 'note2　⇣', 'note3　⇣']
me.Mdataframe.columns.names = ['info1　⇢', 'info2　⇢', 'info3　⇢']

# %%
me.Mdataframe
# Out:
# info1　⇢                   VAR
# info2　⇢                 VAR-A       VAR-B
# info3　⇢                 var-a var-b var-c
# note1　⇣ note2　⇣ note3　⇣
# x       a       1           0     1     2
#                 2           3     4     5
#         b       1           6     7     8
# y       b       2           9    10    11

# %% [markdown]
# #### ``pd.DatetimeIndex``

# %%
me.dates = pd.date_range('1/1/2000', periods=8)

# %%
me.dates
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# #### ``pd.Panel`` - **DEPRECATED, THOUGH pandas is NAMED AFTER IT :)**

# %%
np.random.seed(1) # ⇠ Important for reproducibility of scientific work.

# %%
me.df = pd.DataFrame(np.random.randn(8,4), index=me.dates, columns=['A','B','C','D'])

# %%
me.df
# Out:
#                    A         B         C         D
# 2000-01-01  1.624345 -0.611756 -0.528172 -1.072969
# 2000-01-02  0.865408 -2.301539  1.744812 -0.761207
# 2000-01-03  0.319039 -0.249370  1.462108 -2.060141
# 2000-01-04 -0.322417 -0.384054  1.133769 -1.099891
# 2000-01-05 -0.172428 -0.877858  0.042214  0.582815
# 2000-01-06 -1.100619  1.144724  0.901591  0.502494
# 2000-01-07  0.900856 -0.683728 -0.122890 -0.935769
# 2000-01-08 -0.267888  0.530355 -0.691661 -0.396754

# %% [markdown]
# **THEREFORE BELOW LINE DOESN'T WORK ANYMORE, USE XARRAY INSTEAD**

# %%
#me.panel = pd.Panel({'one': me.df[0:4], 'two': (me.df - me.df.mean())[['A', 'C']]})

# %% [markdown]
# #### **Anatomy of DataFrame**

# %%
me.df.index
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
me.df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
me.df.values
# Out:
# array([[ 1.62434536, -0.61175641, -0.52817175, -1.07296862],
#        [ 0.86540763, -2.3015387 ,  1.74481176, -0.7612069 ],
#        [ 0.3190391 , -0.24937038,  1.46210794, -2.06014071],
#        [-0.3224172 , -0.38405435,  1.13376944, -1.09989127],
#        [-0.17242821, -0.87785842,  0.04221375,  0.58281521],
#        [-1.10061918,  1.14472371,  0.90159072,  0.50249434],
#        [ 0.90085595, -0.68372786, -0.12289023, -0.93576943],
#        [-0.26788808,  0.53035547, -0.69166075, -0.39675353]])

# %% [markdown]
# ### **Xarray Data Types**

# %%
import xarray as xr

# %% [markdown]
# #### ``xr.DataArray``

# %%
me.arr = xr.DataArray([1, 2, 3])

# %%
me.arr
# Out:
# <xarray.DataArray (dim_0: 3)>
# array([1, 2, 3])
# Dimensions without coordinates: dim_0

# %%
me.data = xr.DataArray(np.random.randn(2, 3), dims=("x", "y"), coords={"x": [10, 20]})

# %%
me.data
# Out:
# <xarray.DataArray (x: 2, y: 3)>
# array([[-0.6871727 , -0.84520564, -0.67124613],
#        [-0.0126646 , -1.11731035,  0.2344157 ]])
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y

# %% [markdown]
# #### ``xr.Dataset``

# %%
me.ds = xr.Dataset(
    {'x': (['space'], [1,2]),
     'y': (['time'], [3,4,5])})
me.ds
# Out:
# <xarray.Dataset>
# Dimensions:  (space: 2, time: 3)
# Dimensions without coordinates: space, time
# Data variables:
#     x        (space) int64 1 2
#     y        (time) int64 3 4 5

# %% [markdown]
# #### **NOTE:** Casting: ``pd.DataFrame <= xr.Dataset``

# %%
me.ds.to_dataframe()
# Out:
#             x  y
# space time
# 0     0     1  3
#       1     1  4
#       2     1  5
# 1     0     2  3
#       1     2  4
#       2     2  5

# %% [markdown]
# #### **NOTE:** Casting: ``pd.DataFrame => xr.Dataset``

# %%
me.dfs = pd.DataFrame({'x': [1,2,3], 'y': [4,5,6]})
me.dfs.to_xarray()
# Out:
# <xarray.Dataset>
# Dimensions:  (index: 3)
# Coordinates:
#   * index    (index) int64 0 1 2
# Data variables:
#     x        (index) int64 1 2 3
#     y        (index) int64 4 5 6

# %%
me.ds = xr.Dataset({"foo": me.data,
                    "bar": ("x", [1, 2]),
                    "baz": np.pi})

# %%
me.ds
# Out:
# <xarray.Dataset>
# Dimensions:  (x: 2, y: 3)
# Coordinates:
#   * x        (x) int64 10 20
# Dimensions without coordinates: y
# Data variables:
#     foo      (x, y) float64 -0.6872 -0.8452 -0.6712 -0.01266 -1.117 0.2344
#     bar      (x) int64 1 2
#     baz      float64 3.142

# %% [markdown]
# #### ``Operations across dimensions``

# %%
me.ds.mean(dim='x')
# Out:
# <xarray.Dataset>
# Dimensions:  (y: 3)
# Dimensions without coordinates: y
# Data variables:
#     foo      (y) float64 -0.3499 -0.9813 -0.2184
#     bar      float64 1.5
#     baz      float64 3.142

# %% [markdown]
# **More examples:** [https://gist.github.com/mindey/f06f7c9d2c1aa17950dc16a90f6a9acb](https://gist.github.com/mindey/f06f7c9d2c1aa17950dc16a90f6a9acb)

# %% [markdown]
# ## **Modifying Representations**

# %% [markdown]
# ### **Adding/Removing elements to Series**

# %%
# So we had Series
me.xseries
# Out:
# a    1
# b    2
# 1    3
# dtype: int64

# %%
# Adding an element:
me.xseries['c'] = 4

# %%
# Removing an element
del me.xseries['c']  # or: me.xseries.drop('c') -- to temporarily remove

# %%
# Extending with multiple elements
me.xseries.append(me.yseries)
# Out:
# a    1
# b    2
# 1    3
# a    4
# b    5
# 2    6
# dtype: int64

# %%
# Removing multiple elements
me.xseries.drop(['a', 'b'])
# Out:
# 1    3
# dtype: int64

# %% [markdown]
# ### **Adding Data to DataFrames**

# %%
# So, we had a DataFrame
me.dataframe
# Out:
#    xVar  yVar zVar
# a   1.0   4.0  yes
# b   2.0   5.0   no
# 1   3.0   NaN  yes
# 2   NaN   6.0  yes

# %%
# Adding an element
me.dataframe.at['newRow','newCol'] = 1

# %%
me.df
# Out:
#                    A         B         C         D
# 2000-01-01  1.624345 -0.611756 -0.528172 -1.072969
# 2000-01-02  0.865408 -2.301539  1.744812 -0.761207
# 2000-01-03  0.319039 -0.249370  1.462108 -2.060141
# 2000-01-04 -0.322417 -0.384054  1.133769 -1.099891
# 2000-01-05 -0.172428 -0.877858  0.042214  0.582815
# 2000-01-06 -1.100619  1.144724  0.901591  0.502494
# 2000-01-07  0.900856 -0.683728 -0.122890 -0.935769
# 2000-01-08 -0.267888  0.530355 -0.691661 -0.396754

# %%
# Adding a variable:
me.dataframe['wVar'] = [1, 2, 3, 4, 5]

# %%
me.dataframe
# Out:
#         xVar  yVar zVar  newCol  wVar
# a        1.0   4.0  yes     NaN     1
# b        2.0   5.0   no     NaN     2
# 1        3.0   NaN  yes     NaN     3
# 2        NaN   6.0  yes     NaN     4
# newRow   NaN   NaN  NaN     1.0     5

# %%
# Adding a new Variable: (conforming to indices)
me.dataframe['wVar'] = pd.Series([1,2,3,4,5], index=['b','a',1,2,'newRow'])

# %%
me.dataframe
# Out:
#         xVar  yVar zVar  newCol  wVar
# a        1.0   4.0  yes     NaN     2
# b        2.0   5.0   no     NaN     1
# 1        3.0   NaN  yes     NaN     3
# 2        NaN   6.0  yes     NaN     4
# newRow   NaN   NaN  NaN     1.0     5

# %% [markdown]
# ### **Renaming a Variable**

# %%
# Produce a new DataFrame with the columns renamed:
me.dataframe.rename(columns={'wVar' : 'newCol2'}).head(2)
# Out:
#    xVar  yVar zVar  newCol  newCol2
# a   1.0   4.0  yes     NaN        2
# b   2.0   5.0   no     NaN        1

# %%
# Rename the columns inside original DataFrame
me.dataframe.rename(columns={'wVar' : 'newCol2'}, inplace=True)

# %% [markdown]
# ### **Adding Variables and Observations to Multi-Index**

# %%
# We had Multi-Indexed Dataframe:
me.Mdataframe
# Out:
# info1　⇢                   VAR
# info2　⇢                 VAR-A       VAR-B
# info3　⇢                 var-a var-b var-c
# note1　⇣ note2　⇣ note3　⇣
# x       a       1           0     1     2
#                 2           3     4     5
#         b       1           6     7     8
# y       b       2           9    10    11

# %% [markdown]
# #### **Variable**

# %%
# Adding a Variable to it:
me.Mdataframe[('VAR','VAR-B','var-d')] = 1

# %%
me.Mdataframe
# Out:
# info1　⇢                   VAR
# info2　⇢                 VAR-A       VAR-B
# info3　⇢                 var-a var-b var-c var-d
# note1　⇣ note2　⇣ note3　⇣
# x       a       1           0     1     2     1
#                 2           3     4     5     1
#         b       1           6     7     8     1
# y       b       2           9    10    11     1

# %%
# Adding self-defined Variable to it:
newVar = pd.Series([1, 2], index=pd.MultiIndex.from_tuples([('x','a',1), ('x','a',2)]))
me.Mdataframe[('VAR','VAR-B','var-d')] = newVar

# %%
me.Mdataframe
# Out:
# info1　⇢                   VAR
# info2　⇢                 VAR-A       VAR-B
# info3　⇢                 var-a var-b var-c var-d
# note1　⇣ note2　⇣ note3　⇣
# x       a       1           0     1     2   1.0
#                 2           3     4     5   2.0
#         b       1           6     7     8   NaN
# y       b       2           9    10    11   NaN

# %% [markdown]
# #### **Observation**

# %%
# Adding a new Observatio
me.Mdataframe.append(pd.Series([1, 2, 3, 4], name=('y', 'b', 3), index=me.Mdataframe.columns))
# Out:
# info1　⇢                   VAR
# info2　⇢                 VAR-A       VAR-B
# info3　⇢                 var-a var-b var-c var-d
# note1　⇣ note2　⇣ note3　⇣
# x       a       1           0     1     2   1.0
#                 2           3     4     5   2.0
#         b       1           6     7     8   NaN
# y       b       2           9    10    11   NaN
#                 3           1     2     3   4.0

# %% [markdown]
# ### **Removing Data from DataFrame**

# %%
# So we had:
me.dataframe
# Out:
#         xVar  yVar zVar  newCol  newCol2
# a        1.0   4.0  yes     NaN        2
# b        2.0   5.0   no     NaN        1
# 1        3.0   NaN  yes     NaN        3
# 2        NaN   6.0  yes     NaN        4
# newRow   NaN   NaN  NaN     1.0        5

# %%
# Removing Observations:
me.dataframe.drop(['a', 'b'])
# Out:
#         xVar  yVar zVar  newCol  newCol2
# 1        3.0   NaN  yes     NaN        3
# 2        NaN   6.0  yes     NaN        4
# newRow   NaN   NaN  NaN     1.0        5

# %%
me.Mdataframe.drop([('y', 'b'), ('x', 'b')])
# Out:
# info1　⇢                   VAR
# info2　⇢                 VAR-A       VAR-B
# info3　⇢                 var-a var-b var-c var-d
# note1　⇣ note2　⇣ note3　⇣
# x       a       1           0     1     2   1.0
#                 2           3     4     5   2.0

# %%
# Removing Variables:
me.dataframe.drop(['newCol', 'newCol2'], axis=1)
# Out:
#         xVar  yVar zVar
# a        1.0   4.0  yes
# b        2.0   5.0   no
# 1        3.0   NaN  yes
# 2        NaN   6.0  yes
# newRow   NaN   NaN  NaN

# %%
me.Mdataframe.drop([('VAR','VAR-B','var-d')], axis=1)
# Out:
# info1　⇢                   VAR
# info2　⇢                 VAR-A       VAR-B
# info3　⇢                 var-a var-b var-c
# note1　⇣ note2　⇣ note3　⇣
# x       a       1           0     1     2
#                 2           3     4     5
#         b       1           6     7     8
# y       b       2           9    10    11

# %% [markdown]
# ## **Combining Representations**

# %% [markdown]
# ### Concatenation

# %%
me.df
# Out:
#                    A         B         C         D
# 2000-01-01  1.624345 -0.611756 -0.528172 -1.072969
# 2000-01-02  0.865408 -2.301539  1.744812 -0.761207
# 2000-01-03  0.319039 -0.249370  1.462108 -2.060141
# 2000-01-04 -0.322417 -0.384054  1.133769 -1.099891
# 2000-01-05 -0.172428 -0.877858  0.042214  0.582815
# 2000-01-06 -1.100619  1.144724  0.901591  0.502494
# 2000-01-07  0.900856 -0.683728 -0.122890 -0.935769
# 2000-01-08 -0.267888  0.530355 -0.691661 -0.396754

# %%
df1 = me.df[['A', 'C']]['2000-01-02':'2000-01-04']
df1
# Out:
#                    A         C
# 2000-01-02  0.865408  1.744812
# 2000-01-03  0.319039  1.462108
# 2000-01-04 -0.322417  1.133769

# %%
df2 = me.df[['B', 'C']]['2000-01-07':'2000-01-08']
df2
# Out:
#                    B         C
# 2000-01-07 -0.683728 -0.122890
# 2000-01-08  0.530355 -0.691661

# %%
# Combine vertically (aligning Columns)
pd.concat([df1, df2])
# Out:
#                    A         C         B
# 2000-01-02  0.865408  1.744812       NaN
# 2000-01-03  0.319039  1.462108       NaN
# 2000-01-04 -0.322417  1.133769       NaN
# 2000-01-07       NaN -0.122890 -0.683728
# 2000-01-08       NaN -0.691661  0.530355

# %%
# Combine horizontally (aligning Indexes)
pd.concat([df1, df2], axis=1)
# Out:
#                    A         C         B         C
# 2000-01-02  0.865408  1.744812       NaN       NaN
# 2000-01-03  0.319039  1.462108       NaN       NaN
# 2000-01-04 -0.322417  1.133769       NaN       NaN
# 2000-01-07       NaN       NaN -0.683728 -0.122890
# 2000-01-08       NaN       NaN  0.530355 -0.691661

# %%
# Sub-index with keys:
pd.concat([df1, df2], keys=['group1', 'group2'])
# Out:
#                           A         C         B
# group1 2000-01-02  0.865408  1.744812       NaN
#        2000-01-03  0.319039  1.462108       NaN
#        2000-01-04 -0.322417  1.133769       NaN
# group2 2000-01-07       NaN -0.122890 -0.683728
#        2000-01-08       NaN -0.691661  0.530355

# %%
# Sub-index with keys:
pd.concat([df1, df2], axis=1, keys=['group1', 'group2'])
# Out:
#               group1              group2
#                    A         C         B         C
# 2000-01-02  0.865408  1.744812       NaN       NaN
# 2000-01-03  0.319039  1.462108       NaN       NaN
# 2000-01-04 -0.322417  1.133769       NaN       NaN
# 2000-01-07       NaN       NaN -0.683728 -0.122890
# 2000-01-08       NaN       NaN  0.530355 -0.691661

# %% [markdown]
# ### **Joining/Merging DataFrames**
#
# #### Inner Join
# `pd.merge(df, df, on='var', how='inner')`
# #### Outer Left Join
# `pd.merge(df, df, on='var', how='left')`
# #### Outer Right Join
# `pd.merge(df, df, on='var', how='right')`
# #### Outer Join
# `pd.merge(df, df, on='var', how='outer')`
# #### Cross Join
# `pd.merge(df, df, on='var')`

# %% [markdown]
# ## **Cleaning Representations**
# #### Removing Observations/Variables with Missing Data
# ``.dropna()``, `
# #### Filling Observations/Variables with Missing Data
# ``fillna()``

# %%
me.Mdataframe
# Out:
# info1　⇢                   VAR
# info2　⇢                 VAR-A       VAR-B
# info3　⇢                 var-a var-b var-c var-d
# note1　⇣ note2　⇣ note3　⇣
# x       a       1           0     1     2   1.0
#                 2           3     4     5   2.0
#         b       1           6     7     8   NaN
# y       b       2           9    10    11   NaN
